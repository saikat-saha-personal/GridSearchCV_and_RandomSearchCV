# %% [markdown]
# https://www.kaggle.com/code/devharal/gridsearchcv-and-randomizedsearchcv/notebook

# %% [markdown]
# ### Learning
#
# https://www.javatpoint.com/hyperparameters-in-machine-learning

# %% [markdown]
# #### GridSearchCV vs RandomSearchCV
# https://www.kaggle.com/general/212697

# %% [markdown]
# 1) GridSearchCV :
# We try every combination of a present list of values of the hyper-parameters and choose the best combination based on the cross validation score.
#
# **-** It takes a lot of time to fit (because it will try all the combinations)
#
# **+** gives us the best hyper-parameters.

# %% [markdown]
# exemple ;
# { 'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 'kernel': ['rbf',’linear’,'sigmoid'] }
#
# in this case we will try 5 * 5 * 3=75 combinations

# %% [markdown]
# 2) RandomSearchCV :
# Tries random combinations of a range of values (we have to define the number of iterations). It is good at testing a wide range of values and normally it reaches a very good combination very fast, but the problem that it doesn’t guarantee to give the best parameter combination because not all parameter values are tried out (recommended for big datasets or high number of parameters to tune.

# %% [markdown]
#    **-**  It doesn't guarantee that we have the best parameters
#
#    **+**  faster because not all parameter values are tried out

# %%
# importing the dependencies
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
# loading the data from sklearn
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()

# %%
type(breast_cancer_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
df = pd.DataFrame(breast_cancer_dataset.data, columns=breast_cancer_dataset.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
# adding the 'target' column to the data frame
df['label'] = breast_cancer_dataset.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
# checking for missing values
df.isna().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
# checking the distribution of Target Varibale
df["label"].value_counts()
# Out:
# 1    357
# 0    212
# Name: label, dtype: int64

# %% [markdown]
# 1 --> Benign
#
# 0 --> Malignant

# %% [markdown]
# Separating the features and target

# %%
X = df.drop(columns='label', axis=1)
Y = df['label']

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
 X = np.asarray(X)
 Y = np.asarray(Y)

# %% [markdown]
# ## GridSearchCV

# %% [markdown]
# GridSearchCV is used for determining the best parameters for our model

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
# grid search
classifier = GridSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([1.06690202e+00, 2.69250870e-03, 3.61504555e-03, 1.46060467e-02,
#         2.16908674e+00, 2.70099640e-03, 2.73308754e-03, 1.00340843e-02,
#         3.07536135e+00, 2.54955292e-03, 2.72965431e-03, 1.01852894e-02,
#         5.74419479e+00, 2.73442268e-03, 2.52399445e-03, 9.87071991e-03]),
#  'std_fit_time': array([4.27578689e-01, 6.21149823e-04, 6.38843935e-04, 4.33720091e-04,
#         4.55216802e-01, 3.35482184e-04, 4.55932646e-04, 4.35110262e-04,
#         7.12624570e-01, 1.24806841e-04, 3.08752115e-04, 4.63306904e-04,
#         2.16344506e+00, 1.19964307e-04, 1.10443824e-04, 4.14018717e-04]),
#  'mean_score_time': array([0.00051427, 0.00071192, 0.00215082, 0.00279355, 0.00048876,
#         0.0006969 , 0.00138664, 0.00232654, 0.00050645, 0.00053153,
#         0.00136595, 0.00224423, 0.00052662, 0.00054502, 0.0011198 ,
#         0.00213242]),
#  'std_score_time': array([3.37589258e-05, 1.52920272e-04, 3.95192108e-04, 2.96552846e-05,
#         2.41323889e-05, 8.13105932e-05, 1.76786757e-04, 1.04118505e-04,
#         4.46451506e-05, 2.79772190e-05, 1.15560224e-04, 1.06440051e-04,
#         7.12643303e-05, 3.00059041e-05, 2.44322165e-05, 3.99269622e-05]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 5, 5, 5, 5, 10, 10, 10, 10, 20, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid', 'linear', 'poly', 'rbf', 'sigmoid',
#                     'linear', 'poly', 'rbf', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'sigmoid'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'poly'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'sigmoid'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([0.94736842, 0.84210526, 0.85087719, 0.54385965, 0.94736842,
#         0.88596491, 0.88596491, 0.49122807, 0.93859649, 0.88596491,
#         0.87719298, 0.48245614, 0.92982456, 0.87719298, 0.87719298,
#         0.47368421]),
#  'split1_test_score': array([0.92982456, 0.88596491, 0.89473684, 0.45614035, 0.93859649,
#         0.9122807 , 0.92982456, 0.42105263, 0.93859649, 0.92105263,
#         0.92105263, 0.40350877, 0.95614035, 0.92105263, 0.92105263,
#         0.40350877]),
#  'split2_test_score': array([0.97368421, 0.92982456, 0.92982456, 0.46491228, 0.97368421,
#         0.92105263, 0.93859649, 0.42105263, 0.97368421, 0.90350877,
#         0.9122807 , 0.42105263, 0.95614035, 0.90350877, 0.92105263,
#         0.42105263]),
#  'split3_test_score': array([0.92105263, 0.94736842, 0.94736842, 0.38596491, 0.92982456,
#         0.93859649, 0.94736842, 0.35087719, 0.94736842, 0.93859649,
#         0.95614035, 0.34210526, 0.93859649, 0.93859649, 0.94736842,
#         0.34210526]),
#  'split4_test_score': array([0.95575221, 0.9380531 , 0.9380531 , 0.45132743, 0.96460177,
#         0.95575221, 0.95575221, 0.37168142, 0.96460177, 0.95575221,
#         0.94690265, 0.36283186, 0.96460177, 0.95575221, 0.9380531 ,
#         0.3539823 ]),
#  'mean_test_score': array([0.94553641, 0.90866325, 0.91217202, 0.46044093, 0.95081509,
#         0.92272939, 0.93150132, 0.41117839, 0.95256948, 0.920975  ,
#         0.92271386, 0.40239093, 0.9490607 , 0.91922062, 0.92094395,
#         0.39886664]),
#  'std_test_score': array([0.01868869, 0.03938232, 0.03544367, 0.05025317, 0.01621632,
#         0.02368918, 0.02435811, 0.04857818, 0.01419963, 0.02470123,
#         0.02787898, 0.0489065 , 0.01281637, 0.02730027, 0.02410455,
#         0.0476401 ]),
#  'rank_test_score': array([ 4, 12, 11, 13,  2,  6,  5, 14,  1,  8,  7, 15,  3, 10,  9, 16],
#        dtype=int32)}

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.shape
# Out:
# (16, 15)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       1.066902      0.427579         0.000514        0.000034       1
# 1       0.002693      0.000621         0.000712        0.000153       1
# 2       0.003615      0.000639         0.002151        0.000395       1
# 3       0.014606      0.000434         0.002794        0.000030       1
# 4       2.169087      0.455217         0.000489        0.000024       5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.929825           0.973684           0.921053           0.955752
# 1           0.885965           0.929825           0.947368           0.938053
# 2           0.894737           0.929825           0.947368           0.938053
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.938596           0.973684           0.929825           0.964602
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.945536        0.018689                4
# 1         0.908663        0.039382               12
# 2         0.912172        0.035444               11
# 3         0.460441        0.050253               13
# 4         0.950815        0.016216                2

# %%
grid_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
grid_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.945536
# 1        1         poly         0.908663
# 2        1          rbf         0.912172
# 3        1      sigmoid         0.460441
# 4        5       linear         0.950815
# 5        5         poly         0.922729
# 6        5          rbf         0.931501
# 7        5      sigmoid         0.411178
# 8       10       linear         0.952569
# 9       10         poly         0.920975
# 10      10          rbf         0.922714
# 11      10      sigmoid         0.402391
# 12      20       linear         0.949061
# 13      20         poly         0.919221
# 14      20          rbf         0.920944
# 15      20      sigmoid         0.398867

# %% [markdown]
# Highest Accuracy = 95.2%
#
# Best Parameters = {'C':10, 'kernel':'linear'}

# %% [markdown]
# ## RandomizedSearchCV

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
# grid search
classifier = RandomizedSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([5.87854385e-03, 1.57222748e-02, 4.16970253e-03, 1.47730827e-02,
#         3.70432444e+00, 2.59003258e+00, 3.84755135e-03, 1.33867264e-02,
#         6.29396696e+00, 3.63683701e-03]),
#  'std_fit_time': array([1.21544209e-03, 2.84860155e-03, 3.21456898e-04, 2.50008928e-04,
#         1.23259711e+00, 5.44130063e-01, 1.45791384e-04, 6.21245384e-04,
#         1.71577970e+00, 1.65552409e-04]),
#  'mean_score_time': array([0.0018887 , 0.00309649, 0.00220594, 0.00337715, 0.00063186,
#         0.00061178, 0.00075994, 0.00305271, 0.00065074, 0.00077186]),
#  'std_score_time': array([4.12204512e-04, 2.25156710e-04, 1.76634064e-04, 8.65270132e-05,
#         1.34920768e-04, 9.85797830e-05, 6.61836577e-05, 1.97629416e-04,
#         1.19666995e-04, 3.69259814e-05]),
#  'param_kernel': masked_array(data=['poly', 'sigmoid', 'rbf', 'sigmoid', 'linear',
#                     'linear', 'poly', 'sigmoid', 'linear', 'poly'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_C': masked_array(data=[5, 20, 1, 1, 10, 5, 20, 10, 20, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'kernel': 'poly', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 20},
#   {'kernel': 'rbf', 'C': 1},
#   {'kernel': 'sigmoid', 'C': 1},
#   {'kernel': 'linear', 'C': 10},
#   {'kernel': 'linear', 'C': 5},
#   {'kernel': 'poly', 'C': 20},
#   {'kernel': 'sigmoid', 'C': 10},
#   {'kernel': 'linear', 'C': 20},
#   {'kernel': 'poly', 'C': 10}],
#  'split0_test_score': array([0.88596491, 0.47368421, 0.85087719, 0.54385965, 0.93859649,
#         0.94736842, 0.87719298, 0.48245614, 0.92982456, 0.88596491]),
#  'split1_test_score': array([0.9122807 , 0.40350877, 0.89473684, 0.45614035, 0.93859649,
#         0.93859649, 0.92105263, 0.40350877, 0.95614035, 0.92105263]),
#  'split2_test_score': array([0.92105263, 0.42105263, 0.92982456, 0.46491228, 0.97368421,
#         0.97368421, 0.90350877, 0.42105263, 0.95614035, 0.90350877]),
#  'split3_test_score': array([0.93859649, 0.34210526, 0.94736842, 0.38596491, 0.94736842,
#         0.92982456, 0.93859649, 0.34210526, 0.93859649, 0.93859649]),
#  'split4_test_score': array([0.95575221, 0.3539823 , 0.9380531 , 0.45132743, 0.96460177,
#         0.96460177, 0.95575221, 0.36283186, 0.96460177, 0.95575221]),
#  'mean_test_score': array([0.92272939, 0.39886664, 0.91217202, 0.46044093, 0.95256948,
#         0.95081509, 0.91922062, 0.40239093, 0.9490607 , 0.920975  ]),
#  'std_test_score': array([0.02368918, 0.0476401 , 0.03544367, 0.05025317, 0.01419963,
#         0.01621632, 0.02730027, 0.0489065 , 0.01281637, 0.02470123]),
#  'rank_test_score': array([ 4, 10,  7,  8,  1,  2,  6,  9,  3,  5], dtype=int32)}

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.shape
# Out:
# (10, 15)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.005879      0.001215         0.001889        0.000412         poly
# 1       0.015722      0.002849         0.003096        0.000225      sigmoid
# 2       0.004170      0.000321         0.002206        0.000177          rbf
# 3       0.014773      0.000250         0.003377        0.000087      sigmoid
# 4       3.704324      1.232597         0.000632        0.000135       linear
#
#   param_C                          params  split0_test_score  \
# 0       5      {'kernel': 'poly', 'C': 5}           0.885965
# 1      20  {'kernel': 'sigmoid', 'C': 20}           0.473684
# 2       1       {'kernel': 'rbf', 'C': 1}           0.850877
# 3       1   {'kernel': 'sigmoid', 'C': 1}           0.543860
# 4      10   {'kernel': 'linear', 'C': 10}           0.938596
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.912281           0.921053           0.938596           0.955752
# 1           0.403509           0.421053           0.342105           0.353982
# 2           0.894737           0.929825           0.947368           0.938053
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.938596           0.973684           0.947368           0.964602
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.922729        0.023689                4
# 1         0.398867        0.047640               10
# 2         0.912172        0.035444                7
# 3         0.460441        0.050253                8
# 4         0.952569        0.014200                1

# %%
randomized_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
randomized_search_result
# Out:
#   param_C param_kernel  mean_test_score
# 0       5         poly         0.922729
# 1      20      sigmoid         0.398867
# 2       1          rbf         0.912172
# 3       1      sigmoid         0.460441
# 4      10       linear         0.952569
# 5       5       linear         0.950815
# 6      20         poly         0.919221
# 7      10      sigmoid         0.402391
# 8      20       linear         0.949061
# 9      10         poly         0.920975

# %% [markdown]
# Highest Accuracy = 95.2%
#
# Best Parameters = {'C':10, 'kernel':'linear'}
